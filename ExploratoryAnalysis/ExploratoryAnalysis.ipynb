# %%
import pandas as pd;
a=pd.read_csv("/Heart.csv")

# %%
a.head()

# %%
a.tail()

# %%
a.shape

# %%
a.dtypes

# %%
a.min()

# %%
a.max()

# %%
a.mean()

# %%
a.describe()

# %%
a.isnull()

# %%
(a==0).sum

# %%
a["Age"].mean()

# %%
a.rename(columns={'Age':'age' , 'Ca':'ca'} , inplace=True)

# %%
a.describe()
